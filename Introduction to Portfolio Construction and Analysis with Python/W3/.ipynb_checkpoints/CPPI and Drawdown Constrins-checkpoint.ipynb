# %% [markdown]
# # Implementing Portfolio insurance (CPPI) and Drawdown Constrains

# %%
import pandas as pd
import numpy as np
import ashmodule as ash
import matplotlib as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
ind_return = ash.get_idx_returns()
tmi_return = ash.get_total_market_index_returns()
# Out:
# File Accepted
# Denominator Accepted
# File Accepted
# Denominator Accepted

# %%
ash.summary_stats(ind_return,level = 5)
# Out:
#        Annualized Return  Annualized Vol  Skewness   Kurtosis    VaR 5%  \
# Food            0.106649        0.163974  0.047090   9.685942  0.068226
# Beer            0.120041        0.248922  1.767094  25.099855  0.106206
# Smoke           0.122324        0.201206  0.003873   6.238037  0.084150
# Games           0.091829        0.308881  0.640702  12.834406  0.135309
# Books           0.079147        0.247850  0.505608   9.542575  0.108740
# Hshld           0.093513        0.200962  0.378634  15.767173  0.086223
# Clths           0.093518        0.210732  0.306152   7.564461  0.090707
# Hlth            0.116723        0.192703  0.082986   9.655376  0.080671
# Chems           0.107320        0.218022  0.307249   9.389386  0.092979
# Txtls           0.083356        0.265996  0.946878  12.825371  0.116688
# Cnstr           0.086209        0.238219  0.309860   8.732202  0.103798
# Steel           0.067926        0.292022  1.274936  16.026790  0.129697
# FabPr           0.098153        0.249735  0.436389  10.174841  0.108122
# ElcEq           0.109179        0.262667  0.562422  11.477323  0.113157
# Autos           0.094397        0.275035  1.148444  17.063197  0.119941
# Carry           0.107120        0.262226  0.452187   8.613922  0.113116
# Mines           0.075994        0.252297  0.154431   6.378308  0.110974
# Coal            0.062543        0.373938  2.085076  24.544552  0.167033
# Oil             0.101700        0.211075  0.251545   6.714812  0.090237
# Util            0.090147        0.190571  0.077954  11.021351  0.081711
# Telcm           0.092669        0.159056 -0.033990   5.969455  0.067026
# Servs           0.109196        0.288004  1.141170  20.598950  0.124616
# BusEq           0.112490        0.233885 -0.212003   6.239064  0.099779
# Paper           0.106115        0.202983  0.306584   9.605802  0.086197
# Trans           0.084093        0.244961  1.054132  16.291166  0.107081
# Whlsl           0.067420        0.253232  0.631809  15.072992  0.112078
# Rtail           0.107438        0.206729  0.020736   8.816787  0.087791
# Meals           0.106644        0.224011 -0.356591   5.844337  0.095716
# Fin             0.098169        0.234825  0.515471  14.604311  0.101333
# Other           0.068767        0.234123  0.361037   9.544110  0.103290
#
#        Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# Food                0.061207          0.103659      0.454770     -0.722186
# Beer                0.033881          0.145016      0.351780     -0.885744
# Smoke               0.080292          0.122454      0.446361     -0.598755
# Games               0.100701          0.199534      0.194420     -0.958661
# Books               0.088675          0.157187      0.192686     -0.915794
# Hshld               0.064886          0.126263      0.307349     -0.887100
# Clths               0.079707          0.126007      0.293105     -0.762776
# Hlth                0.071884          0.116393      0.437783     -0.746865
# Chems               0.079262          0.129039      0.344903     -0.859568
# Txtls               0.079519          0.159519      0.194906     -0.875844
# Cnstr               0.089668          0.151252      0.229351     -0.887397
# Steel               0.074436          0.174968      0.126052     -0.917775
# FabPr               0.088491          0.157257      0.265297     -0.906982
# ElcEq               0.087624          0.159254      0.293063     -0.928874
# Autos               0.069545          0.165745      0.227548     -0.901429
# Carry               0.094527          0.159952      0.285916     -0.897952
# Mines               0.102782          0.149234      0.177109     -0.861505
# Coal                0.047359          0.212895      0.084275     -0.973579
# Oil                 0.081244          0.125159      0.330358     -0.762190
# Util                0.071585          0.123180      0.306945     -0.856414
# Telcm               0.064719          0.100371      0.383294     -0.717741
# Servs               0.066112          0.169307      0.267263     -0.864965
# BusEq               0.099377          0.150018      0.342974     -0.846242
# Paper               0.073181          0.123554      0.364722     -0.787876
# Trans               0.065468          0.147275      0.214624     -0.910446
# Whlsl               0.080604          0.160939      0.143494     -0.978122
# Rtail               0.080437          0.128134      0.364325     -0.841184
# Meals               0.098403          0.150502      0.332717     -0.843806
# Fin                 0.075199          0.152741      0.282243     -0.921246
# Other               0.087270          0.148509      0.160862     -0.883567

# %%
tmi_return.plot(figsize = (12,6));

# %%
l = ["Steel","Fin","Beer"]
risky_r = ind_return["2000":][l]
ash.summary_stats(risky_r)
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis    VaR 5%  \
# Steel          -0.002790        0.312368 -0.326334  4.144381  0.144050
# Fin             0.055166        0.192909 -0.533218  4.995534  0.085336
# Beer            0.080598        0.138925 -0.493545  4.173881  0.058532
#
#        Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# Steel               0.150139          0.208117     -0.102567     -0.758017
# Fin                 0.091224          0.132175      0.126718     -0.718465
# Beer                0.063015          0.091442      0.354314     -0.271368

# %%
btr = ash.run_cppi(risky_r)
ash.summary_stats(btr["Wealth"].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness   Kurtosis    VaR 5%  \
# Steel          -0.005167        0.174180 -1.995143  17.110190  0.081579
# Fin             0.040894        0.131678 -0.946504   6.051414  0.058304
# Beer            0.075544        0.115462 -0.669250   4.760879  0.048058
#
#        Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# Steel               0.091995          0.130153     -0.196750     -0.655198
# Fin                 0.065535          0.091621      0.080352     -0.549673
# Beer                0.052923          0.074908      0.383772     -0.259582

# %%
ax = btr["Wealth"]["Fin"].plot(figsize = (12,6));
ash.drawdown(risky_r["Fin"])["Wealth"].plot(style = ":");

# %%
tmi_return = ash.get_total_market_index_returns()
tmi_return
# Out:
# File Accepted
# Denominator Accepted
# File Accepted
# Denominator Accepted
# 1926-07    0.031375
# 1926-08    0.028957
# 1926-09    0.005566
# 1926-10   -0.028504
# 1926-11    0.028039
#              ...
# 2018-08    0.036951
# 2018-09    0.002108
# 2018-10   -0.074292
# 2018-11    0.019003
# 2018-12   -0.092911
# Freq: M, Length: 1110, dtype: float64

# %%
btr_2 = ash.run_cppi(tmi_return["2007":])
ax = btr_2["Wealth"].plot(figsize =(12,6), label = "CPPI",legend = False)
btr_2["Risky Wealth"].plot(ax = ax, style = "--",label = "Risky",legend = False)
ax.set_ylim(bottom = 0);

# %%
ash.summary_stats(btr_2["Risky Wealth"].pct_change().dropna())
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis    VaR 5%  \
# R           0.073411        0.150463 -0.734939  4.523488  0.064319
#
#    Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# R               0.071592          0.096315      0.280618     -0.499943

# %%
ash.summary_stats(btr_2["Wealth"].pct_change().dropna())
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis    VaR 5%  \
# R           0.069416        0.100381 -0.588292  3.740932  0.041469
#
#    Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# R               0.045678          0.062953      0.382052     -0.229683

# %% [markdown]
# # Drawdown Constraint

# %%
btr_3 = ash.run_cppi(ind_return["2007":][["Steel","Fin","Beer"]], drawdown = 0.25)

# %%
ax = btr_3["Wealth"].plot(figsize = (12,6));
btr_3["Risky Wealth"].plot(ax=ax, style = ":");

# %%
ash.summary_stats(btr_3["Risky Wealth"].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis    VaR 5%  \
# Steel          -0.039660        0.306407 -0.459951  4.782828  0.144285
# Fin             0.027364        0.212204 -0.695200  4.621401  0.096232
# Beer            0.111554        0.127971 -0.670797  4.650878  0.051015
#
#        Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# Steel               0.152288          0.203837     -0.221642     -0.758017
# Fin                 0.105744          0.149862     -0.012370     -0.718465
# Beer                0.056497          0.077388      0.620132     -0.271368

# %%
ash.summary_stats(btr_3["Wealth"].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis    VaR 5%  \
# Steel           0.003784        0.097073 -0.441089  5.220481  0.045223
# Fin             0.041975        0.085028 -0.355163  4.153860  0.036500
# Beer            0.084375        0.086263 -0.744111  4.571533  0.033734
#
#        Cornish-Fisher VaR 5%  Historic CVaR 5%  Sharpe Ratio  Max Drawdown
# Steel               0.047371          0.066991     -0.262958     -0.248059
# Fin                 0.038342          0.054111      0.136964     -0.243626
# Beer                0.037937          0.051189      0.613413     -0.161186
