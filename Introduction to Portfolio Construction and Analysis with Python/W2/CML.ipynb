# %% [markdown]
# # Cpital Markert Line

# %%
import pandas as pd
import numpy as np 
import ashmodule as ash
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
ind = ash.get_idx_returns()
er = ash.annualize_rets(ind["1960":"2013"],12)
cov = ind["1960":"2013"].cov()

# %%
ash.plot_ef(20,er,cov,show_cml=True, riskfree_rate = 0.1);

# %%
ash.plot_ef(30,er,cov,color = 'black',show_cml=True, riskfree_rate = 0.1,cml_linewidth = 3, cml_markersize = 7,cml_linecolor = "green");

# %%
ash.plot_ef(30,er,cov,color = 'black',show_cml=True, riskfree_rate = 0.1,cml_linewidth = 3, cml_markersize = 7,cml_linecolor = "green",show_ew=True);

# %%
ash.plot_ef(30,er,cov,color = 'black',show_cml=True, riskfree_rate = 0.1,cml_linewidth = 3, cml_markersize = 7,cml_linecolor = "green",show_ew=True, ew_markersize = 20,show_gmv=True,gmv_color="yellow");
